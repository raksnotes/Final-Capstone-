# %%
# opening configuration file, saving into a variable, then establishing that variable as env which specifies the data as development
# environment credentials


with open('sql/config.json') as datafile:
    data = json.load(datafile)

env = data['dev']

# %%
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from flask import Flask, jsonify
from sqlalchemy.engine import url
import json
from sqlalchemy import extract
from sqlalchemy.engine import make_url
import psycopg2
from sqlalchemy.sql import text

# %%
# Instantiating the environment column values as the column names to hide sensitive data

db = env['db']
user = env['user']
password = env['pass']
port = env['port']
host = env['host']

# %%
# Connection string

engine = sqlalchemy.create_engine(f'postgresql://{user}:{password}@{host}:{port}/{db}')

# %%
# Reflecting an existing DB into a new model
Base = automap_base()

# %%
#Trying another method reflecting tables

Base.prepare(autoload_with = engine)

# %%
# Seeing what tables there are

Base.classes.keys()
# Out:
# ['jhu_cre_cases_deaths', 'location']

# %%
# Saving the tables as references here if u want 

location = Base.classes.location

# %%
# Another table reference 

jhu_data = Base.classes.jhu_cre_cases_deaths

# %%
# Create our session from python to DB
#Create a session object to intiiate query in db

from sqlalchemy.orm import sessionmaker

Session = sessionmaker(bind = engine)
session = Session()

# %%
# Test query to make sure database connection works

query = session.query(jhu_data)

# %%
#SQL only accepts str vals so have to convert query into string so that its readable by sql, but then we have a df we can
# manipulate however. This should not fail and allow you to do whatever with the data. (No more worries abt csvs etc yay!)

jhucredf = pd.DataFrame(engine.connect().execute(str(query)))

# %%
jhucredf
# Out:
#          0      1    2          3           4         5                  6   \
# 0      1001  19732  230  32.539527  -86.644082   Alabama     Autauga County
# 1      1003  69641  724  30.727750  -87.722071   Alabama     Baldwin County
# 2      1005   7451  103  31.868263  -85.387129   Alabama     Barbour County
# 3      1007   8067  109  32.996421  -87.125115   Alabama        Bibb County
# 4      1009  18616  261  33.982109  -86.567906   Alabama      Blount County
# ...     ...    ...  ...        ...         ...       ...                ...
# 3137  56037  12484  139  41.659439 -108.882788   Wyoming  Sweetwater County
# 3138  56039  12123   16  43.935225 -110.589080   Wyoming       Teton County
# 3139  56041   6378   43  41.287818 -110.547578   Wyoming       Uinta County
# 3140  56043   2749   50  43.904516 -107.680187   Wyoming    Washakie County
# 3141  56045   1903   23  43.839612 -104.567488   Wyoming      Weston County
#
#           7       8      9   ...    31   32      33    34      35     36  \
# 0      55688   55380  20573  ...   723  111   49283   779   29291   3953
# 1     221898  212830  78622  ...  2218  887  201483  3994  112058  19748
# 2      22023   25361   5024  ...   220  132   16120   572    8170   2488
# 3      20393   22493   6280  ...   346  163   16130   265    8096   2182
# 4      57697   57681  18189  ...  1038  115   46446  1961   27463   6231
# ...      ...     ...    ...  ...   ...  ...     ...   ...     ...    ...
# 3137   41888   43521  16977  ...   502  209   38872  1298   21739   4733
# 3138   23390   23280   7250  ...   140  771   22267  1777   13028   2970
# 3139   20183   20479   7744  ...   322  141   18709   322   10091   2260
# 3140    7738    8027   2601  ...   108   77    6948   108    3869   1160
# 3141    6664    7049   1857  ...   179   26    6244    13    3531    786
#
#           37    38    39     40
# 0      44884  2450   779   1726
# 1     181512  7322  7322  96747
# 2      13323  2246   836   1629
# 3      14111  1264   305   1142
# 4      42118  2365   403   4846
# ...      ...   ...   ...    ...
# 3137   35185   712   879  12817
# 3138   20372   561   467   5730
# 3139   18063   686   100   2401
# 3140    6051   379    15   1903
# 3141    5117   166   139   1299
#
# [3142 rows x 41 columns]

# %%
sql = '''
    SELECT * FROM jhu_cre_cases_deaths;
'''
with engine.connect() as conn:
    query = conn.execute(text(sql))
df = pd.DataFrame(query.fetchall())

# %%
df.head()
# Out:
#      0      1    2          3          4         5               6       7   \
# 0  1001  19732  230  32.539527 -86.644082   Alabama  Autauga County   55688
# 1  1003  69641  724  30.727750 -87.722071   Alabama  Baldwin County  221898
# 2  1005   7451  103  31.868263 -85.387129   Alabama  Barbour County   22023
# 3  1007   8067  109  32.996421 -87.125115   Alabama     Bibb County   20393
# 4  1009  18616  261  33.982109 -86.567906   Alabama   Blount County   57697
#
#        8      9   ...    31   32      33    34      35     36      37    38  \
# 0   55380  20573  ...   723  111   49283   779   29291   3953   44884  2450
# 1  212830  78622  ...  2218  887  201483  3994  112058  19748  181512  7322
# 2   25361   5024  ...   220  132   16120   572    8170   2488   13323  2246
# 3   22493   6280  ...   346  163   16130   265    8096   2182   14111  1264
# 4   57681  18189  ...  1038  115   46446  1961   27463   6231   42118  2365
#
#      39     40
# 0   779   1726
# 1  7322  96747
# 2   836   1629
# 3   305   1142
# 4   403   4846
#
# [5 rows x 41 columns]

# %%
import os
data = os.path.join("JHU_Cases_Deaths_with_CRE_Data_2_0.csv")

df = pd.read_csv(data)

df.columns
# Out:
# Index(['fips', 'cases', 'deaths', 'lat', 'long', 'state', 'county', 'popuni',
#        'total_population', 'zero_rf', 'one_two_rf', 'three_rf',
#        'housing_units', 'hispanic_pop', 'white_pop', 'black_pop', 'native_pop',
#        'asian_pop', 'pacific_islander_pop', 'other_race_pop',
#        'bi_tri_racial_pop', 'male_pop', 'female_pop', 'veteran',
#        'gini_ind_income', 'rural_pop', 'median_age_pop', 'elder_pop',
#        'disability_pop', 'below_poverty_level', 'single_mothers_pop',
#        'single_fathers_pop', 'plus_family_homes', 'highschool_grad',
#        'multilingual_5yrs_plus', 'full_time_workers', 'no_health_insur',
#        'internet_homes', 'no_vehicle', 'homeowner_vacancy', 'rental_vacancy'],
#       dtype='object')

# %%
df.head()
# Out:
#    fips  cases  deaths        lat       long     state          county  \
# 0  1001  19732     230  32.539527 -86.644082   Alabama  Autauga County
# 1  1003  69641     724  30.727750 -87.722071   Alabama  Baldwin County
# 2  1005   7451     103  31.868263 -85.387129   Alabama  Barbour County
# 3  1007   8067     109  32.996421 -87.125115   Alabama     Bibb County
# 4  1009  18616     261  33.982109 -86.567906   Alabama   Blount County
#
#    popuni  total_population  zero_rf  ...  single_fathers_pop  \
# 0   55688             55380    20573  ...                 723
# 1  221898            212830    78622  ...                2218
# 2   22023             25361     5024  ...                 220
# 3   20393             22493     6280  ...                 346
# 4   57697             57681    18189  ...                1038
#
#    plus_family_homes  highschool_grad  multilingual_5yrs_plus  \
# 0                111            49283                     779
# 1                887           201483                    3994
# 2                132            16120                     572
# 3                163            16130                     265
# 4                115            46446                    1961
#
#    full_time_workers  no_health_insur  internet_homes  no_vehicle  \
# 0              29291             3953           44884        2450
# 1             112058            19748          181512        7322
# 2               8170             2488           13323        2246
# 3               8096             2182           14111        1264
# 4              27463             6231           42118        2365
#
#    homeowner_vacancy  rental_vacancy
# 0                779            1726
# 1               7322           96747
# 2                836            1629
# 3                305            1142
# 4                403            4846
#
# [5 rows x 41 columns]

# %%
death_catlow = 0
death_catmed = 110
death_catintermed = 261
death_cathigh = 369
death_catveryhigh = 35250

# Iterate over each row and assign a category based on the 'deaths' column
for (index, row) in df.iterrows():
    deaths = row['deaths']
    if deaths <= death_catlow:
        df.at[index, 'death_cat'] = 'low'
    elif deaths <= death_catmed:
        df.at[index, 'death_cat'] = 'med'
    elif deaths <= death_catintermed:
        df.at[index, 'death_cat'] = 'intermed'
    elif deaths <= death_cathigh:
        df.at[index, 'death_cat'] = 'high'
    else:
        df.at[index, 'death_cat'] = 'veryhigh'

# %%
# Define the death thresholds
death_catlow <= 47
death_catmed <= 110
death_catintermed <= 261
death_cathigh <= 369


# Iterate over each row and assign a category based on the 'deaths' column
for (index, row) in df.iterrows():
    deaths = row['deaths']
    if deaths <= death_catlow:
        df.at[index, 'death_cat'] = 'low'
    elif deaths <= death_catmed:
        df.at[index, 'death_cat'] = 'med'
    elif deaths <= death_catintermed:
        df.at[index, 'death_cat'] = 'intermed'
    else:
        df.at[index, 'death_cat'] = 'high'

# %%
death_catlow = 47
death_catmed = 110
death_cathigh = 261

for index, row in df.iterrows():
    deaths = row['deaths']
    if deaths <= death_catlow:
        df.loc[index, 'death_cat'] = 'low'
    elif death_catlow < deaths <= death_catmed:
        df.loc[index, 'death_cat'] = 'med'
    else:
        df.loc[index, 'death_cat'] = 'high'
        
death_catlow = 47
death_catmed = 110
death_catintermed = 261
death_cathigh = 369
count = 0
for (column, columnData) in dfd.iterrows():
    deaths = dfd['deaths'].values[count]
    dc = dfd['death_cat']
    if deaths <= death_catlow:
        dc.values[count] = 'low'
    elif deaths > death_catlow and deaths <= death_catmed:
        dc.values[count] = 'med'
    elif deaths > death_catmed and deaths <= death_catintermed:
        dc.values[count] = 'intermed'
    else:
        dc.values[count] = 'high'
    count = count + 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'death_cat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15712\1588443969.py in <module>
#       6 for (column, columnData) in df.iterrows():
#       7     deaths = df['deaths'].values[count]
# ----> 8     dc = df['death_cat']
#       9     if deaths <= death_catlow:
#      10         dc.values[count] = 'low'
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'death_cat'

# %%
df.head(10)
# Out:
#    fips  cases  deaths        lat       long     state           county  \
# 0  1001  19732     230  32.539527 -86.644082   Alabama   Autauga County
# 1  1003  69641     724  30.727750 -87.722071   Alabama   Baldwin County
# 2  1005   7451     103  31.868263 -85.387129   Alabama   Barbour County
# 3  1007   8067     109  32.996421 -87.125115   Alabama      Bibb County
# 4  1009  18616     261  33.982109 -86.567906   Alabama    Blount County
# 5  1011   3020      54  32.100305 -85.712655   Alabama   Bullock County
# 6  1013   6518     132  31.753001 -86.680575   Alabama    Butler County
# 7  1015  41228     675  33.774837 -85.826304   Alabama   Calhoun County
# 8  1017  10812     170  32.913601 -85.390727   Alabama  Chambers County
# 9  1019   6732      89  34.178060 -85.606390   Alabama  Cherokee County
#
#    popuni  total_population  zero_rf  ...  plus_family_homes  highschool_grad  \
# 0   55688             55380    20573  ...                111            49283
# 1  221898            212830    78622  ...                887           201483
# 2   22023             25361     5024  ...                132            16120
# 3   20393             22493     6280  ...                163            16130
# 4   57697             57681    18189  ...                115            46446
# 5    8600             10248     2074  ...                  0             6424
# 6   19410             19828     5431  ...                116            16498
# 7  111694            114618    35169  ...                446            94269
# 8   33117             33660     9457  ...               1192            27023
# 9   26116             25903     7374  ...                130            21310
#
#    multilingual_5yrs_plus  full_time_workers  no_health_insur  internet_homes  \
# 0                     779              29291             3953           44884
# 1                    3994             112058            19748          181512
# 2                     572               8170             2488           13323
# 3                     265               8096             2182           14111
# 4                    1961              27463             6231           42118
# 5                      86               4274              980            5168
# 6                      77               9200             1688           12538
# 7                    1675              51267            10610           83882
# 8                     430              16889             3411           22983
# 9                     182              12718             2245           18464
#
#    no_vehicle  homeowner_vacancy  rental_vacancy  death_cat
# 0        2450                779            1726   intermed
# 1        7322               7322           96747       high
# 2        2246                836            1629        med
# 3        1264                305            1142        med
# 4        2365                403            4846   intermed
# 5         920                 17              60        med
# 6        1455                718            4503   intermed
# 7        6701               2345            6254       high
# 8        2417                894            3079   intermed
# 9        1175                861            3577        med
#
# [10 rows x 42 columns]

# %%
df.to_csv("JHU_updated_category.csv", index = False)

# %%
df.drop(columns=(["lat","long","state","county","fips"]), inplace= True)

# %%
df.dtypes
# Out:
# fips                        int64
# cases                       int64
# deaths                      int64
# lat                       float64
# long                      float64
# state                      object
# county                     object
# popuni                      int64
# total_population            int64
# zero_rf                     int64
# one_two_rf                  int64
# three_rf                    int64
# housing_units               int64
# hispanic_pop                int64
# white_pop                   int64
# black_pop                   int64
# native_pop                  int64
# asian_pop                   int64
# pacific_islander_pop        int64
# other_race_pop              int64
# bi_tri_racial_pop           int64
# male_pop                    int64
# female_pop                  int64
# veteran                     int64
# gini_ind_income             int64
# rural_pop                   int64
# median_age_pop              int64
# elder_pop                   int64
# disability_pop              int64
# below_poverty_level         int64
# single_mothers_pop          int64
# single_fathers_pop          int64
# plus_family_homes           int64
# highschool_grad             int64
# multilingual_5yrs_plus      int64
# full_time_workers           int64
# no_health_insur             int64
# internet_homes              int64
# no_vehicle                  int64
# homeowner_vacancy           int64
# rental_vacancy              int64
# death_cat                  object
# dtype: object

# %%
df
# Out:
#       cases  deaths  popuni  total_population  zero_rf  one_two_rf  three_rf  \
# 0     19732     230   55688             55380    20573       22750     12365
# 1     69641     724  221898            212830    78622       90552     52724
# 2      7451     103   22023             25361     5024        9171      7828
# 3      8067     109   20393             22493     6280        8986      5127
# 4     18616     261   57697             57681    18189       23950     15558
# ...     ...     ...     ...               ...      ...         ...       ...
# 3137  12484     139   41888             43521    16977       17781      7130
# 3138  12123      16   23390             23280     7250       11567      4573
# 3139   6378      43   20183             20479     7744        9346      3093
# 3140   2749      50    7738              8027     2601        3215      1922
# 3141   1903      23    6664              7049     1857        3367      1440
#
#       housing_units  hispanic_pop  white_pop  ...  plus_family_homes  \
# 0             23493          1559      41543  ...                111
# 1            114164         10207     184397  ...                887
# 2             12013           969      10086  ...                132
# 3              9185           530      15192  ...                163
# 4             24323          5365      50138  ...                115
# ...             ...           ...        ...  ...                ...
# 3137          19771          6660      33342  ...                209
# 3138          13848          3508      19016  ...                771
# 3139           9041          1836      17660  ...                141
# 3140           3860          1098       6337  ...                 77
# 3141           3562            73       6424  ...                 26
#
#       highschool_grad  multilingual_5yrs_plus  full_time_workers  \
# 0               49283                     779              29291
# 1              201483                    3994             112058
# 2               16120                     572               8170
# 3               16130                     265               8096
# 4               46446                    1961              27463
# ...               ...                     ...                ...
# 3137            38872                    1298              21739
# 3138            22267                    1777              13028
# 3139            18709                     322              10091
# 3140             6948                     108               3869
# 3141             6244                      13               3531
#
#       no_health_insur  internet_homes  no_vehicle  homeowner_vacancy  \
# 0                3953           44884        2450                779
# 1               19748          181512        7322               7322
# 2                2488           13323        2246                836
# 3                2182           14111        1264                305
# 4                6231           42118        2365                403
# ...               ...             ...         ...                ...
# 3137             4733           35185         712                879
# 3138             2970           20372         561                467
# 3139             2260           18063         686                100
# 3140             1160            6051         379                 15
# 3141              786            5117         166                139
#
#       rental_vacancy  death_cat
# 0               1726          0
# 1              96747          0
# 2               1629          2
# 3               1142          2
# 4               4846          0
# ...              ...        ...
# 3137           12817          0
# 3138            5730          1
# 3139            2401          1
# 3140            1903          2
# 3141            1299          1
#
# [3142 rows x 37 columns]

# %%
death_catlow = 47
death_catmed = 110
death_cathigh = 261

for index, row in df.iterrows():
    deaths = row['deaths']
    if deaths <= death_catlow:
        df.loc[index, 'death_cat'] = 'low'
    elif death_catlow < deaths <= death_catmed:
        df.loc[index, 'death_cat'] = 'med'
    else:
        df.loc[index, 'death_cat'] = 'high'

# %% [markdown]
# df.columns

# %%
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
#PCA (Principal Component Analysis)
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %% [markdown]
# # Linear Regression Model against Risk Factors

# %%
from sklearn.preprocessing import LabelEncoder
df['death_cat'] = LabelEncoder().fit_transform(df['death_cat'])

# %%
df.head(10)
# Out:
#    fips  cases  deaths        lat       long     state           county  \
# 0  1001  19732     230  32.539527 -86.644082   Alabama   Autauga County
# 1  1003  69641     724  30.727750 -87.722071   Alabama   Baldwin County
# 2  1005   7451     103  31.868263 -85.387129   Alabama   Barbour County
# 3  1007   8067     109  32.996421 -87.125115   Alabama      Bibb County
# 4  1009  18616     261  33.982109 -86.567906   Alabama    Blount County
# 5  1011   3020      54  32.100305 -85.712655   Alabama   Bullock County
# 6  1013   6518     132  31.753001 -86.680575   Alabama    Butler County
# 7  1015  41228     675  33.774837 -85.826304   Alabama   Calhoun County
# 8  1017  10812     170  32.913601 -85.390727   Alabama  Chambers County
# 9  1019   6732      89  34.178060 -85.606390   Alabama  Cherokee County
#
#    popuni  total_population  zero_rf  ...  plus_family_homes  highschool_grad  \
# 0   55688             55380    20573  ...                111            49283
# 1  221898            212830    78622  ...                887           201483
# 2   22023             25361     5024  ...                132            16120
# 3   20393             22493     6280  ...                163            16130
# 4   57697             57681    18189  ...                115            46446
# 5    8600             10248     2074  ...                  0             6424
# 6   19410             19828     5431  ...                116            16498
# 7  111694            114618    35169  ...                446            94269
# 8   33117             33660     9457  ...               1192            27023
# 9   26116             25903     7374  ...                130            21310
#
#    multilingual_5yrs_plus  full_time_workers  no_health_insur  internet_homes  \
# 0                     779              29291             3953           44884
# 1                    3994             112058            19748          181512
# 2                     572               8170             2488           13323
# 3                     265               8096             2182           14111
# 4                    1961              27463             6231           42118
# 5                      86               4274              980            5168
# 6                      77               9200             1688           12538
# 7                    1675              51267            10610           83882
# 8                     430              16889             3411           22983
# 9                     182              12718             2245           18464
#
#    no_vehicle  homeowner_vacancy  rental_vacancy  death_cat
# 0        2450                779            1726          0
# 1        7322               7322           96747          0
# 2        2246                836            1629          2
# 3        1264                305            1142          2
# 4        2365                403            4846          0
# 5         920                 17              60          2
# 6        1455                718            4503          0
# 7        6701               2345            6254          0
# 8        2417                894            3079          0
# 9        1175                861            3577          2
#
# [10 rows x 42 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
X = df[["zero_rf","one_two_rf","three_rf"
      ]]
y= df['death_cat']

# %%
from sklearn import linear_model

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# from sklearn.linear_model import LogisticRegression
# classifier = LogisticRegression()
# classifier

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Fit the model to the training data, and calculate the scores for the training and testing data.

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.13983849291045303
# Testing Score: 0.09791650132753138

# %%
# Calculate the mean_squared_error and the r-squared value
# for the testing data

from sklearn.metrics import mean_squared_error, r2_score

### BEGIN SOLUTION

# Use our model to make predictions
predicted = model.predict(X_test)

# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print(f"mean squared error (MSE): {mse}")
print(f"R-squared (R2): {r2}")
# Out:
# mean squared error (MSE): 1.3299641261239017
# R-squared (R2): 0.09791650132753138

# %%
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
plt.show()

# %%
model.score(X_test, y_test)
# Out:
# 0.09791650132753138

# %%
death_catlow = 47
death_catmed = 110
death_cathigh = 261

for index, row in df.iterrows():
    deaths = row['deaths']
    if deaths <= death_catlow:
        df.loc[index, 'death_cat'] = 'low'
    elif death_catlow < deaths <= death_catmed:
        df.loc[index, 'death_cat'] = 'med'
    else:
        df.loc[index, 'death_cat'] = 'high'

# %%
df.head()
# Out:
#    fips  cases  deaths        lat       long     state          county  \
# 0  1001  19732     230  32.539527 -86.644082   Alabama  Autauga County
# 1  1003  69641     724  30.727750 -87.722071   Alabama  Baldwin County
# 2  1005   7451     103  31.868263 -85.387129   Alabama  Barbour County
# 3  1007   8067     109  32.996421 -87.125115   Alabama     Bibb County
# 4  1009  18616     261  33.982109 -86.567906   Alabama   Blount County
#
#    popuni  total_population  zero_rf  ...  plus_family_homes  highschool_grad  \
# 0   55688             55380    20573  ...                111            49283
# 1  221898            212830    78622  ...                887           201483
# 2   22023             25361     5024  ...                132            16120
# 3   20393             22493     6280  ...                163            16130
# 4   57697             57681    18189  ...                115            46446
#
#    multilingual_5yrs_plus  full_time_workers  no_health_insur  internet_homes  \
# 0                     779              29291             3953           44884
# 1                    3994             112058            19748          181512
# 2                     572               8170             2488           13323
# 3                     265               8096             2182           14111
# 4                    1961              27463             6231           42118
#
#    no_vehicle  homeowner_vacancy  rental_vacancy  death_cat
# 0        2450                779            1726       high
# 1        7322               7322           96747       high
# 2        2246                836            1629        med
# 3        1264                305            1142        med
# 4        2365                403            4846       high
#
# [5 rows x 42 columns]

# %% [markdown]
# # Logistic Regression on risk Factors

# %%
from sklearn.preprocessing import LabelEncoder
df['death_cat'] = LabelEncoder().fit_transform(df['death_cat'])

# %%
df.head()
# Out:
#    fips  cases  deaths        lat       long     state          county  \
# 0  1001  19732     230  32.539527 -86.644082   Alabama  Autauga County
# 1  1003  69641     724  30.727750 -87.722071   Alabama  Baldwin County
# 2  1005   7451     103  31.868263 -85.387129   Alabama  Barbour County
# 3  1007   8067     109  32.996421 -87.125115   Alabama     Bibb County
# 4  1009  18616     261  33.982109 -86.567906   Alabama   Blount County
#
#    popuni  total_population  zero_rf  ...  plus_family_homes  highschool_grad  \
# 0   55688             55380    20573  ...                111            49283
# 1  221898            212830    78622  ...                887           201483
# 2   22023             25361     5024  ...                132            16120
# 3   20393             22493     6280  ...                163            16130
# 4   57697             57681    18189  ...                115            46446
#
#    multilingual_5yrs_plus  full_time_workers  no_health_insur  internet_homes  \
# 0                     779              29291             3953           44884
# 1                    3994             112058            19748          181512
# 2                     572               8170             2488           13323
# 3                     265               8096             2182           14111
# 4                    1961              27463             6231           42118
#
#    no_vehicle  homeowner_vacancy  rental_vacancy  death_cat
# 0        2450                779            1726          1
# 1        7322               7322           96747          0
# 2        2246                836            1629          3
# 3        1264                305            1142          3
# 4        2365                403            4846          1
#
# [5 rows x 42 columns]

# %%
df.columns
# Out:
# Index(['fips', 'cases', 'deaths', 'lat', 'long', 'state', 'county', 'popuni',
#        'total_population', 'zero_rf', 'one_two_rf', 'three_rf',
#        'housing_units', 'hispanic_pop', 'white_pop', 'black_pop', 'native_pop',
#        'asian_pop', 'pacific_islander_pop', 'other_race_pop',
#        'bi_tri_racial_pop', 'male_pop', 'female_pop', 'veteran',
#        'gini_ind_income', 'rural_pop', 'median_age_pop', 'elder_pop',
#        'disability_pop', 'below_poverty_level', 'single_mothers_pop',
#        'single_fathers_pop', 'plus_family_homes', 'highschool_grad',
#        'multilingual_5yrs_plus', 'full_time_workers', 'no_health_insur',
#        'internet_homes', 'no_vehicle', 'homeowner_vacancy', 'rental_vacancy',
#        'death_cat'],
#       dtype='object')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# X = df[['disability_pop'
#       ]]

# X = df[["three_rf"]]
# X = df[["zero_rf"]]
X = df[["disability_pop"]]
y= df['death_cat']

# %%
df.head()
# Out:
#    zero_rf  one_two_rf  three_rf  housing_units  hispanic_pop  white_pop  \
# 0    20573       22750     12365          23493          1559      41543
# 1    78622       90552     52724         114164         10207     184397
# 2     5024        9171      7828          12013           969      10086
# 3     6280        8986      5127           9185           530      15192
# 4    18189       23950     15558          24323          5365      50138
#
#    black_pop  native_pop  asian_pop  pacific_islander_pop  ...  \
# 0      10580         167        556                     0  ...
# 1      20414        1553       1997                     0  ...
# 2      10438          66        110                     0  ...
# 3       4506          20         20                     0  ...
# 4        865          57        230                     0  ...
#
#    plus_family_homes  highschool_grad  multilingual_5yrs_plus  \
# 0                111            49283                     779
# 1                887           201483                    3994
# 2                132            16120                     572
# 3                163            16130                     265
# 4                115            46446                    1961
#
#    full_time_workers  no_health_insur  internet_homes  no_vehicle  \
# 0              29291             3953           44884        2450
# 1             112058            19748          181512        7322
# 2               8170             2488           13323        2246
# 3               8096             2182           14111        1264
# 4              27463             6231           42118        2365
#
#    homeowner_vacancy  rental_vacancy  death_cat
# 0                779            1726          1
# 1               7322           96747          0
# 2                836            1629          3
# 3                305            1142          3
# 4                403            4846          1
#
# [5 rows x 33 columns]

# %%
print(X)
print(y)
# Out:
#       disability_pop
# 0              10580
# 1              31509
# 2               4712
# 3               3507
# 4               8135
# ...              ...
# 3137            5571
# 3138            1613
# 3139            3370
# 3140            1098
# 3141             892
#
# [3142 rows x 1 columns]
# 0       1
# 1       0
# 2       3
# 3       3
# 4       1
#        ..
# 3137    1
# 3138    3
# 3139    3
# 3140    3
# 3141    3
# Name: death_cat, Length: 3142, dtype: int32

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=50)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(max_iter=500)
classifier
# Out:
# LogisticRegression(max_iter=500)

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.8471986417657046
# Testing Data Score: 0.8422391857506362

# %%
# Predict the class (purple or yellow) of the new data point
predictions = classifier.predict(X_test)
print("Classes are either 0 (low) or 1 (med) or 2 (high)")
print(f"The new point was classified as: {predictions}")
# Out:
# Classes are either 0 (low) or 1 (med) or 2 (high)
# The new point was classified as: [3 3 3 0 3 3 3 3 0 3 1 3 3 1 1 0 1 3 1 3 1 3 3 3 0 0 1 0 1 3 3 3 3 3 3 3 1
#  3 1 3 3 0 3 1 1 3 0 3 1 3 1 0 3 3 3 1 3 0 3 0 3 3 1 3 3 3 3 0 3 3 0 1 3 3
#  3 0 0 3 0 3 3 3 1 0 0 0 1 3 3 1 3 0 3 0 3 3 3 1 0 3 3 3 0 3 3 1 1 3 3 3 0
#  1 3 1 3 3 0 0 0 3 1 1 0 1 3 1 0 0 1 3 3 1 0 0 0 0 3 3 0 1 1 3 0 3 1 3 3 0
#  3 3 3 3 1 0 3 0 3 1 3 1 3 3 3 1 0 1 3 3 1 3 1 3 0 0 3 3 0 3 0 3 3 1 3 1 3
#  3 3 1 3 0 3 3 1 1 3 3 0 1 3 3 0 1 1 3 1 1 3 1 3 1 1 0 1 0 1 1 1 3 3 1 3 1
#  3 3 3 1 3 3 3 3 3 3 3 1 3 3 1 3 0 3 1 3 0 0 3 1 1 3 3 0 1 3 0 3 0 1 3 1 3
#  3 3 0 0 0 3 3 3 3 0 3 3 3 3 3 3 3 3 0 0 3 3 3 1 1 3 3 1 3 0 0 3 1 0 1 0 3
#  0 3 0 3 3 3 3 1 1 3 1 3 1 1 3 1 3 3 0 1 3 3 3 1 1 3 1 0 0 3 3 1 0 0 3 3 3
#  1 3 3 1 1 3 3 3 0 1 3 1 3 3 3 3 3 1 3 1 0 0 0 3 3 1 3 1 0 3 3 0 0 1 3 3 3
#  0 3 1 3 1 0 3 0 3 1 3 3 3 1 1 1 0 0 0 0 3 3 1 3 1 3 0 3 3 1 3 3 3 3 1 0 3
#  1 3 1 1 1 3 1 3 1 3 3 3 1 3 3 3 1 3 0 1 3 3 3 1 3 1 3 1 0 3 1 1 1 0 0 3 0
#  3 1 3 0 1 0 0 1 3 3 3 3 3 0 3 0 1 3 1 1 3 3 1 3 3 0 3 1 3 3 0 3 0 1 3 3 3
#  3 1 3 3 0 3 3 3 3 0 0 3 0 3 0 3 1 3 3 3 3 3 0 1 3 3 3 3 1 3 3 0 1 0 3 0 0
#  1 1 1 1 3 0 1 1 0 3 0 0 1 0 0 1 3 0 3 0 3 3 3 3 0 3 0 3 3 3 0 3 3 1 3 0 1
#  3 0 3 0 0 3 3 3 3 0 3 1 0 3 3 0 3 3 3 3 3 1 0 0 1 0 1 3 0 3 3 3 0 0 3 3 1
#  3 3 0 0 0 1 3 0 3 3 1 0 1 3 3 3 3 3 0 3 0 0 3 3 3 3 3 0 3 3 3 1 3 3 1 3 3
#  0 3 3 3 3 3 1 3 1 3 0 3 1 3 3 3 0 3 0 3 0 3 3 1 1 1 3 0 3 3 3 3 3 3 0 0 3
#  3 0 3 1 3 3 0 3 3 3 0 0 3 3 3 0 1 1 3 0 1 3 0 3 3 3 1 1 3 3 1 1 3 1 1 0 3
#  1 3 0 3 1 3 3 3 3 0 0 1 0 3 0 3 3 1 3 0 3 3 3 3 3 3 1 3 0 3 0 3 3 1 3 3 3
#  0 0 1 3 0 0 3 0 3 0 1 1 3 3 3 3 3 1 3 3 3 0 3 3 1 1 0 0 3 1 3 3 0 1 0 1 3
#  1 3 3 0 3 0 1 3 0]

# %%
predictions = classifier.predict(X_test)
pd.DataFrame({"Prediction": predictions, "Actual": y_test})
# Out:
#       Prediction  Actual
# 1361           3       1
# 2850           3       3
# 2767           3       1
# 2457           1       0
# 2492           3       3
# ...          ...     ...
# 2563           3       3
# 1399           0       0
# 1318           1       1
# 2646           3       3
# 1208           0       0
#
# [786 rows x 2 columns]

# %%
df.head(10)
# Out:
#    zero_rf  one_two_rf  three_rf  housing_units  hispanic_pop  white_pop  \
# 0    20573       22750     12365          23493          1559      41543
# 1    78622       90552     52724         114164         10207     184397
# 2     5024        9171      7828          12013           969      10086
# 3     6280        8986      5127           9185           530      15192
# 4    18189       23950     15558          24323          5365      50138
# 5     2074        3534      2992           4557           223       1840
# 6     5431        7643      6336          10089           271      10015
# 7    35169       44189     32336          53631          4244      80531
# 8     9457       12798     10862          16988           794      18379
# 9     7374       11044      7698          16579           417      23948
#
#    black_pop  native_pop  asian_pop  pacific_islander_pop  ...  \
# 0      10580         167        556                     0  ...
# 1      20414        1553       1997                     0  ...
# 2      10438          66        110                     0  ...
# 3       4506          20         20                     0  ...
# 4        865          57        230                     0  ...
# 5       6432           0         43                     0  ...
# 6       8734          19         58                     0  ...
# 7      23120         223       1005                     0  ...
# 8      13114          99        364                     0  ...
# 9       1201         287         52                     0  ...
#
#    plus_family_homes  highschool_grad  multilingual_5yrs_plus  \
# 0                111            49283                     779
# 1                887           201483                    3994
# 2                132            16120                     572
# 3                163            16130                     265
# 4                115            46446                    1961
# 5                  0             6424                      86
# 6                116            16498                      77
# 7                446            94269                    1675
# 8               1192            27023                     430
# 9                130            21310                     182
#
#    full_time_workers  no_health_insur  internet_homes  no_vehicle  \
# 0              29291             3953           44884        2450
# 1             112058            19748          181512        7322
# 2               8170             2488           13323        2246
# 3               8096             2182           14111        1264
# 4              27463             6231           42118        2365
# 5               4274              980            5168         920
# 6               9200             1688           12538        1455
# 7              51267            10610           83882        6701
# 8              16889             3411           22983        2417
# 9              12718             2245           18464        1175
#
#    homeowner_vacancy  rental_vacancy  death_cat
# 0                779            1726          1
# 1               7322           96747          0
# 2                836            1629          3
# 3                305            1142          3
# 4                403            4846          1
# 5                 17              60          3
# 6                718            4503          1
# 7               2345            6254          0
# 8                894            3079          1
# 9                861            3577          3
#
# [10 rows x 33 columns]

# %%
# Loop over all columns and run logistic regression
for column in columns:

    X = df[[column]]
    y = df['death_cat']

    # Scale the data
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y)

    # Creatig duplicate for back testing
    X_test_2 = X_test

    # Building logistic regression model on training data
    classifier = LogisticRegression(max_iter=5000).fit(X_train, y_train)
    death_pred = classifier.predict(X_test)

    print(f"Training Data Score: {classifier.score(X_train, y_train)}")
    
    
    print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
    
    # Accuracy statistics
    
    print(f"Column: {column}, Accuracy Score: {metrics.accuracy_score(y_test, death_pred)}")
# Out:
# Training Data Score: 0.7886247877758913
# Testing Data Score: 0.7964376590330788
# Column: zero_rf, Accuracy Score: 0.7964376590330788
# Training Data Score: 0.8174872665534805
# Testing Data Score: 0.8206106870229007
# Column: one_two_rf, Accuracy Score: 0.8206106870229007
# Training Data Score: 0.8501697792869269
# Testing Data Score: 0.8371501272264631
# Column: three_rf, Accuracy Score: 0.8371501272264631
# Training Data Score: 0.8064516129032258
# Testing Data Score: 0.787531806615776
# Column: housing_units, Accuracy Score: 0.787531806615776
# Training Data Score: 0.6345500848896435
# Testing Data Score: 0.6259541984732825
# Column: hispanic_pop, Accuracy Score: 0.6259541984732825
# Training Data Score: 0.24830220713073006
# Testing Data Score: 0.25190839694656486
# Column: white_pop, Accuracy Score: 0.25190839694656486
# Training Data Score: 0.6192699490662139
# Testing Data Score: 0.6335877862595419
# Column: black_pop, Accuracy Score: 0.6335877862595419
# Training Data Score: 0.515704584040747
# Testing Data Score: 0.5114503816793893
# Column: native_pop, Accuracy Score: 0.5114503816793893
# Training Data Score: 0.6502546689303905
# Testing Data Score: 0.6526717557251909
# Column: asian_pop, Accuracy Score: 0.6526717557251909
# Training Data Score: 0.5415959252971138
# Testing Data Score: 0.5508905852417303
# Column: pacific_islander_pop, Accuracy Score: 0.5508905852417303
# Training Data Score: 0.6651103565365025
# Testing Data Score: 0.6755725190839694
# Column: other_race_pop, Accuracy Score: 0.6755725190839694
# Training Data Score: 0.7067062818336163
# Testing Data Score: 0.732824427480916
# Column: bi_tri_racial_pop, Accuracy Score: 0.732824427480916
# Training Data Score: 0.2538200339558574
# Testing Data Score: 0.23536895674300254
# Column: male_pop, Accuracy Score: 0.23536895674300254
# Training Data Score: 0.24745331069609508
# Testing Data Score: 0.2544529262086514
# Column: female_pop, Accuracy Score: 0.2544529262086514
# Training Data Score: 0.7865025466893039
# Testing Data Score: 0.7913486005089059
# Column: veteran, Accuracy Score: 0.7913486005089059
# Training Data Score: 0.8280984719864176
# Testing Data Score: 0.8256997455470738
# Column: gini_ind_income, Accuracy Score: 0.8256997455470738
# Training Data Score: 0.7062818336162988
# Testing Data Score: 0.7213740458015268
# Column: rural_pop, Accuracy Score: 0.7213740458015268
# Training Data Score: 0.25509337860780984
# Testing Data Score: 0.23155216284987276
# Column: median_age_pop, Accuracy Score: 0.23155216284987276
# Training Data Score: 0.8145161290322581
# Testing Data Score: 0.8104325699745547
# Column: elder_pop, Accuracy Score: 0.8104325699745547
# Training Data Score: 0.8455008488964346
# Testing Data Score: 0.8498727735368957
# Column: disability_pop, Accuracy Score: 0.8498727735368957
# Training Data Score: 0.8196095076400679
# Testing Data Score: 0.7938931297709924
# Column: below_poverty_level, Accuracy Score: 0.7938931297709924
# Training Data Score: 0.8166383701188455
# Testing Data Score: 0.8002544529262087
# Column: single_mothers_pop, Accuracy Score: 0.8002544529262087
# Training Data Score: 0.7707979626485568
# Testing Data Score: 0.7811704834605598
# Column: single_fathers_pop, Accuracy Score: 0.7811704834605598
# Training Data Score: 0.6799660441426146
# Testing Data Score: 0.6857506361323156
# Column: plus_family_homes, Accuracy Score: 0.6857506361323156
# Training Data Score: 0.25254668930390495
# Testing Data Score: 0.23918575063613232
# Column: highschool_grad, Accuracy Score: 0.23918575063613232
# Training Data Score: 0.6676570458404074
# Testing Data Score: 0.6272264631043257
# Column: multilingual_5yrs_plus, Accuracy Score: 0.6272264631043257
# Training Data Score: 0.8051782682512734
# Testing Data Score: 0.8027989821882952
# Column: full_time_workers, Accuracy Score: 0.8027989821882952
# Training Data Score: 0.7767402376910016
# Testing Data Score: 0.7938931297709924
# Column: no_health_insur, Accuracy Score: 0.7938931297709924
# Training Data Score: 0.2470288624787776
# Testing Data Score: 0.25572519083969464
# Column: internet_homes, Accuracy Score: 0.25572519083969464
# Training Data Score: 0.7890492359932089
# Testing Data Score: 0.7862595419847328
# Column: no_vehicle, Accuracy Score: 0.7862595419847328
# Training Data Score: 0.7533955857385399
# Testing Data Score: 0.767175572519084
# Column: homeowner_vacancy, Accuracy Score: 0.767175572519084
# Training Data Score: 0.7533955857385399
# Testing Data Score: 0.7493638676844784
# Column: rental_vacancy, Accuracy Score: 0.7493638676844784

# %%
print(columns)
# Out:
# Index(['zero_rf', 'one_two_rf', 'three_rf', 'housing_units', 'hispanic_pop',
#        'white_pop', 'black_pop', 'native_pop', 'asian_pop',
#        'pacific_islander_pop', 'other_race_pop', 'bi_tri_racial_pop',
#        'male_pop', 'female_pop', 'veteran', 'gini_ind_income', 'rural_pop',
#        'median_age_pop', 'elder_pop', 'disability_pop', 'below_poverty_level',
#        'single_mothers_pop', 'single_fathers_pop', 'plus_family_homes',
#        'highschool_grad', 'multilingual_5yrs_plus', 'full_time_workers',
#        'no_health_insur', 'internet_homes', 'no_vehicle', 'homeowner_vacancy',
#        'rental_vacancy'],
#       dtype='object')

# %%
## https://stackoverflow.com/questions/71451255/for-loop-logistic-regression-in-python

# %%
## https://stackoverflow.com/questions/40758562/can-anyone-explain-me-standardscaler
