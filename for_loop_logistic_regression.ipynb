# %%
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from flask import Flask, jsonify
from sqlalchemy.engine import url
import json
from sqlalchemy import extract
from sqlalchemy.engine import make_url
import psycopg2
from sqlalchemy.sql import text
import os
data = os.path.join("JHU_Cases_Deaths_with_CRE_Data_2_0.csv")

df = pd.read_csv(data)

df.columns
# Out:
# Index(['fips', 'cases', 'deaths', 'lat', 'long', 'state', 'county', 'popuni',
#        'total_population', 'zero_rf', 'one_two_rf', 'three_rf',
#        'housing_units', 'hispanic_pop', 'white_pop', 'black_pop', 'native_pop',
#        'asian_pop', 'pacific_islander_pop', 'other_race_pop',
#        'bi_tri_racial_pop', 'male_pop', 'female_pop', 'veteran',
#        'gini_ind_income', 'rural_pop', 'median_age_pop', 'elder_pop',
#        'disability_pop', 'below_poverty_level', 'single_mothers_pop',
#        'single_fathers_pop', 'plus_family_homes', 'highschool_grad',
#        'multilingual_5yrs_plus', 'full_time_workers', 'no_health_insur',
#        'internet_homes', 'no_vehicle', 'homeowner_vacancy', 'rental_vacancy'],
#       dtype='object')

# %%
# Define the death thresholds
death_catlow = 47
death_catmed = 110
death_catintermed = 261
death_cathigh = 369


# Iterate over each row and assign a category based on the 'deaths' column
for (index, row) in df.iterrows():
    deaths = row['deaths']
    if deaths <= death_catlow:
        df.at[index, 'death_cat'] = 'low'
    elif deaths <= death_catmed:
        df.at[index, 'death_cat'] = 'med'
    elif deaths <= death_catintermed:
        df.at[index, 'death_cat'] = 'intermed'
    else:
        df.at[index, 'death_cat'] = 'high'

# %%
df.drop(columns=(["lat","long","state","county","fips",'popuni','total_population','cases', 'deaths']), inplace= True)

# %%
df.columns
# Out:
# Index(['zero_rf', 'one_two_rf', 'three_rf', 'housing_units', 'hispanic_pop',
#        'white_pop', 'black_pop', 'native_pop', 'asian_pop',
#        'pacific_islander_pop', 'other_race_pop', 'bi_tri_racial_pop',
#        'male_pop', 'female_pop', 'veteran', 'gini_ind_income', 'rural_pop',
#        'median_age_pop', 'elder_pop', 'disability_pop', 'below_poverty_level',
#        'single_mothers_pop', 'single_fathers_pop', 'plus_family_homes',
#        'highschool_grad', 'multilingual_5yrs_plus', 'full_time_workers',
#        'no_health_insur', 'internet_homes', 'no_vehicle', 'homeowner_vacancy',
#        'rental_vacancy', 'death_cat'],
#       dtype='object')

# %%
import pandas as pd
import sklearn
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
#PCA (Principal Component Analysis)
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
from sklearn.preprocessing import LabelEncoder
df['death_cat'] = LabelEncoder().fit_transform(df['death_cat'])

# %%
df.head()
# Out:
#    zero_rf  one_two_rf  three_rf  housing_units  hispanic_pop  white_pop  \
# 0    20573       22750     12365          23493          1559      41543
# 1    78622       90552     52724         114164         10207     184397
# 2     5024        9171      7828          12013           969      10086
# 3     6280        8986      5127           9185           530      15192
# 4    18189       23950     15558          24323          5365      50138
#
#    black_pop  native_pop  asian_pop  pacific_islander_pop  ...  \
# 0      10580         167        556                     0  ...
# 1      20414        1553       1997                     0  ...
# 2      10438          66        110                     0  ...
# 3       4506          20         20                     0  ...
# 4        865          57        230                     0  ...
#
#    plus_family_homes  highschool_grad  multilingual_5yrs_plus  \
# 0                111            49283                     779
# 1                887           201483                    3994
# 2                132            16120                     572
# 3                163            16130                     265
# 4                115            46446                    1961
#
#    full_time_workers  no_health_insur  internet_homes  no_vehicle  \
# 0              29291             3953           44884        2450
# 1             112058            19748          181512        7322
# 2               8170             2488           13323        2246
# 3               8096             2182           14111        1264
# 4              27463             6231           42118        2365
#
#    homeowner_vacancy  rental_vacancy  death_cat
# 0                779            1726          1
# 1               7322           96747          0
# 2                836            1629          3
# 3                305            1142          3
# 4                403            4846          1
#
# [5 rows x 33 columns]

# %%
# Loop over all columns and run logistic regression
for column in columns:

    X = df[[column]]
    y = df['death_cat']

    # Scale the data
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    #split the data into training

    X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=20, stratify= y, test_size=0.25)


    # Building logistic regression model on training data
    classifier = LogisticRegression(max_iter=5000).fit(X_train, y_train)
    death_pred = classifier.predict(X_test)

    print(f"Training Data Score: {classifier.score(X_train, y_train)}")
    
    
    print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
    
    # Accuracy statistics
    
    print(f"Column: {column}, Accuracy Score: {metrics.accuracy_score(y_test, death_pred)}")
    print("--------------------------------------------------------------------------------")
# Out:
# Training Data Score: 0.24915110356536502
# Testing Data Score: 0.24936386768447838
# Column: zero_rf, Accuracy Score: 0.24936386768447838
# --------------------------------------------------------------------------------
# Training Data Score: 0.24915110356536502
# Testing Data Score: 0.24936386768447838
# Column: one_two_rf, Accuracy Score: 0.24936386768447838
# --------------------------------------------------------------------------------
# Training Data Score: 0.7771646859083192
# Testing Data Score: 0.8142493638676844
# Column: three_rf, Accuracy Score: 0.8142493638676844
# --------------------------------------------------------------------------------
# Training Data Score: 0.24915110356536502
# Testing Data Score: 0.24936386768447838
# Column: housing_units, Accuracy Score: 0.24936386768447838
# --------------------------------------------------------------------------------
# Training Data Score: 0.45755517826825126
# Testing Data Score: 0.4541984732824427
# Column: hispanic_pop, Accuracy Score: 0.4541984732824427
# --------------------------------------------------------------------------------
# Training Data Score: 0.24915110356536502
# Testing Data Score: 0.24936386768447838
# Column: white_pop, Accuracy Score: 0.24936386768447838
# --------------------------------------------------------------------------------
# Training Data Score: 0.45500848896434637
# Testing Data Score: 0.4872773536895674
# Column: black_pop, Accuracy Score: 0.4872773536895674
# --------------------------------------------------------------------------------
# Training Data Score: 0.3357385398981324
# Testing Data Score: 0.31297709923664124
# Column: native_pop, Accuracy Score: 0.31297709923664124
# --------------------------------------------------------------------------------
# Training Data Score: 0.4830220713073005
# Testing Data Score: 0.494910941475827
# Column: asian_pop, Accuracy Score: 0.494910941475827
# --------------------------------------------------------------------------------
# Training Data Score: 0.35271646859083194
# Testing Data Score: 0.361323155216285
# Column: pacific_islander_pop, Accuracy Score: 0.361323155216285
# --------------------------------------------------------------------------------
# Training Data Score: 0.4970288624787776
# Testing Data Score: 0.5152671755725191
# Column: other_race_pop, Accuracy Score: 0.5152671755725191
# --------------------------------------------------------------------------------
# Training Data Score: 0.5738539898132428
# Testing Data Score: 0.6005089058524173
# Column: bi_tri_racial_pop, Accuracy Score: 0.6005089058524173
# --------------------------------------------------------------------------------
# Training Data Score: 0.24915110356536502
# Testing Data Score: 0.24936386768447838
# Column: male_pop, Accuracy Score: 0.24936386768447838
# --------------------------------------------------------------------------------
# Training Data Score: 0.24915110356536502
# Testing Data Score: 0.24936386768447838
# Column: female_pop, Accuracy Score: 0.24936386768447838
# --------------------------------------------------------------------------------
# Training Data Score: 0.6926994906621392
# Testing Data Score: 0.6984732824427481
# Column: veteran, Accuracy Score: 0.6984732824427481
# --------------------------------------------------------------------------------
# Training Data Score: 0.7470288624787776
# Testing Data Score: 0.7697201017811705
# Column: gini_ind_income, Accuracy Score: 0.7697201017811705
# --------------------------------------------------------------------------------
# Training Data Score: 0.2436332767402377
# Testing Data Score: 0.2506361323155216
# Column: rural_pop, Accuracy Score: 0.2506361323155216
# --------------------------------------------------------------------------------
# Training Data Score: 0.24915110356536502
# Testing Data Score: 0.24936386768447838
# Column: median_age_pop, Accuracy Score: 0.24936386768447838
# --------------------------------------------------------------------------------
# Training Data Score: 0.7338709677419355
# Testing Data Score: 0.7353689567430025
# Column: elder_pop, Accuracy Score: 0.7353689567430025
# --------------------------------------------------------------------------------
# Training Data Score: 0.7678268251273345
# Testing Data Score: 0.7748091603053435
# Column: disability_pop, Accuracy Score: 0.7748091603053435
# --------------------------------------------------------------------------------
# Training Data Score: 0.7330220713073005
# Testing Data Score: 0.7455470737913485
# Column: below_poverty_level, Accuracy Score: 0.7455470737913485
# --------------------------------------------------------------------------------
# Training Data Score: 0.7198641765704584
# Testing Data Score: 0.7493638676844784
# Column: single_mothers_pop, Accuracy Score: 0.7493638676844784
# --------------------------------------------------------------------------------
# Training Data Score: 0.6511035653650254
# Testing Data Score: 0.6513994910941476
# Column: single_fathers_pop, Accuracy Score: 0.6513994910941476
# --------------------------------------------------------------------------------
# Training Data Score: 0.5258913412563667
# Testing Data Score: 0.5381679389312977
# Column: plus_family_homes, Accuracy Score: 0.5381679389312977
# --------------------------------------------------------------------------------
# Training Data Score: 0.24915110356536502
# Testing Data Score: 0.24936386768447838
# Column: highschool_grad, Accuracy Score: 0.24936386768447838
# --------------------------------------------------------------------------------
# Training Data Score: 0.4961799660441426
# Testing Data Score: 0.4872773536895674
# Column: multilingual_5yrs_plus, Accuracy Score: 0.4872773536895674
# --------------------------------------------------------------------------------
# Training Data Score: 0.24915110356536502
# Testing Data Score: 0.24936386768447838
# Column: full_time_workers, Accuracy Score: 0.24936386768447838
# --------------------------------------------------------------------------------
# Training Data Score: 0.6731748726655348
# Testing Data Score: 0.7061068702290076
# Column: no_health_insur, Accuracy Score: 0.7061068702290076
# --------------------------------------------------------------------------------
# Training Data Score: 0.24915110356536502
# Testing Data Score: 0.24936386768447838
# Column: internet_homes, Accuracy Score: 0.24936386768447838
# --------------------------------------------------------------------------------
# Training Data Score: 0.7054329371816639
# Testing Data Score: 0.7086513994910941
# Column: no_vehicle, Accuracy Score: 0.7086513994910941
# --------------------------------------------------------------------------------
# Training Data Score: 0.6320033955857386
# Testing Data Score: 0.6310432569974554
# Column: homeowner_vacancy, Accuracy Score: 0.6310432569974554
# --------------------------------------------------------------------------------
# Training Data Score: 0.620118845500849
# Testing Data Score: 0.6157760814249363
# Column: rental_vacancy, Accuracy Score: 0.6157760814249363
# --------------------------------------------------------------------------------
