# %%
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from flask import Flask, jsonify
from sqlalchemy.engine import url
import json
from sqlalchemy import extract
from sqlalchemy.engine import make_url
from sqlalchemy.orm import sessionmaker
from sqlalchemy.sql import text
import psycopg2

# %%
## I included really anything in here if you actually wanted to run sql queries.

# %%
# opening configuration file, saving into a variable, then establishing that variable as env which specifies the data as development
# environment credentials
with open('sql/config.json') as datafile:
    data = json.load(datafile)

env = data['dev']
print(env)
# Out:
# {'db': 'CRE_COVID_DB', 'user': 'postgres', 'pass': 'Markishot23!', 'host': '127.0.0.1', 'port': '5432'}

# %%
# Instantiating the environment column values as the column names to hide sensitive data
db = env['db']
user = env['user']
password = env['pass']
port = env['port']
host = env['host']

# %%
# Connection string
engine = sqlalchemy.create_engine(
    f'postgresql://{user}:{password}@{host}:{port}/{db}')

# %%
# Reflecting an existing DB into a new model
Base = automap_base()

# %%
Base.prepare(autoload_with = engine)

# %%
# Seeing what tables there are
Base.classes.keys()
# Out:
# ['races', 'cases', 'jhu_cre_cases_deaths', 'location']

# %%
# Saving the tables as references here if u want 
location = Base.classes.location

# %%
# Another table reference 
jhu_data = Base.classes.jhu_cre_cases_deaths

# %%
# Session object is the handler to the database, estb convo w db.
# Sessionmaker class creates a 'top level' session configuration that then can be used throughout the application without
# the need to repeat config arguments.'- Credit to rfkortekaas on Stack for explaining.
Session = sessionmaker(bind = engine)
session = Session()

# %%
# Test query to make sure database connection works
sql = session.query(jhu_data)

# %%
# An example of using sql commands:
sql = '''
    SELECT * FROM location;
'''

with engine.connect() as conn:
    query = conn.execute(text(sql))
df = pd.DataFrame(query.fetchall())

# %%
df
# Out:
#        fips        lat        long     state             county
# 0      1001  32.539527  -86.644082   Alabama     Autauga County
# 1      1003  30.727750  -87.722071   Alabama     Baldwin County
# 2      1005  31.868263  -85.387129   Alabama     Barbour County
# 3      1007  32.996421  -87.125115   Alabama        Bibb County
# 4      1009  33.982109  -86.567906   Alabama      Blount County
# ...     ...        ...         ...       ...                ...
# 3137  56037  41.659439 -108.882788   Wyoming  Sweetwater County
# 3138  56039  43.935225 -110.589080   Wyoming       Teton County
# 3139  56041  41.287818 -110.547578   Wyoming       Uinta County
# 3140  56043  43.904516 -107.680187   Wyoming    Washakie County
# 3141  56045  43.839612 -104.567488   Wyoming      Weston County
#
# [3142 rows x 5 columns]

# %%
# An example of using sql commands:
sql = '''
    SELECT * FROM jhu_cre_cases_deaths;
'''

with engine.connect() as conn:
    query = conn.execute(text(sql))
df2 = pd.DataFrame(query.fetchall())

# %%
df2
# Out:
#        fips  cases  deaths        lat        long     state  \
# 0      1001  19732     230  32.539527  -86.644082   Alabama
# 1      1003  69641     724  30.727750  -87.722071   Alabama
# 2      1005   7451     103  31.868263  -85.387129   Alabama
# 3      1007   8067     109  32.996421  -87.125115   Alabama
# 4      1009  18616     261  33.982109  -86.567906   Alabama
# ...     ...    ...     ...        ...         ...       ...
# 3137  56037  12484     139  41.659439 -108.882788   Wyoming
# 3138  56039  12123      16  43.935225 -110.589080   Wyoming
# 3139  56041   6378      43  41.287818 -110.547578   Wyoming
# 3140  56043   2749      50  43.904516 -107.680187   Wyoming
# 3141  56045   1903      23  43.839612 -104.567488   Wyoming
#
#                  county  popuni  total_population  zero_rf  ...  \
# 0        Autauga County   55688             55380    20573  ...
# 1        Baldwin County  221898            212830    78622  ...
# 2        Barbour County   22023             25361     5024  ...
# 3           Bibb County   20393             22493     6280  ...
# 4         Blount County   57697             57681    18189  ...
# ...                 ...     ...               ...      ...  ...
# 3137  Sweetwater County   41888             43521    16977  ...
# 3138       Teton County   23390             23280     7250  ...
# 3139       Uinta County   20183             20479     7744  ...
# 3140    Washakie County    7738              8027     2601  ...
# 3141      Weston County    6664              7049     1857  ...
#
#       single_fathers_pop  plus_family_homes  highschool_grad  \
# 0                    723                111            49283
# 1                   2218                887           201483
# 2                    220                132            16120
# 3                    346                163            16130
# 4                   1038                115            46446
# ...                  ...                ...              ...
# 3137                 502                209            38872
# 3138                 140                771            22267
# 3139                 322                141            18709
# 3140                 108                 77             6948
# 3141                 179                 26             6244
#
#       multilingual_5yrs_plus  full_time_workers  no_health_insur  \
# 0                        779              29291             3953
# 1                       3994             112058            19748
# 2                        572               8170             2488
# 3                        265               8096             2182
# 4                       1961              27463             6231
# ...                      ...                ...              ...
# 3137                    1298              21739             4733
# 3138                    1777              13028             2970
# 3139                     322              10091             2260
# 3140                     108               3869             1160
# 3141                      13               3531              786
#
#       internet_homes  no_vehicle  homeowner_vacancy  rental_vacancy
# 0              44884        2450                779            1726
# 1             181512        7322               7322           96747
# 2              13323        2246                836            1629
# 3              14111        1264                305            1142
# 4              42118        2365                403            4846
# ...              ...         ...                ...             ...
# 3137           35185         712                879           12817
# 3138           20372         561                467            5730
# 3139           18063         686                100            2401
# 3140            6051         379                 15            1903
# 3141            5117         166                139            1299
#
# [3142 rows x 41 columns]

# %%
df_copy = df2
df_copy.columns
# Out:
# Index(['fips', 'cases', 'deaths', 'lat', 'long', 'state', 'county', 'popuni',
#        'total_population', 'zero_rf', 'one_two_rf', 'three_rf',
#        'housing_units', 'hispanic_pop', 'white_pop', 'black_pop', 'native_pop',
#        'asian_pop', 'pacific_islander_pop', 'other_race_pop',
#        'bi_tri_racial_pop', 'male_pop', 'female_pop', 'veteran',
#        'gini_ind_income', 'rural_pop', 'median_age_pop', 'elder_pop',
#        'disability_pop', 'below_poverty_level', 'single_mothers_pop',
#        'single_fathers_pop', 'plus_family_homes', 'highschool_grad',
#        'multilingual_5yrs_plus', 'full_time_workers', 'no_health_insur',
#        'internet_homes', 'no_vehicle', 'homeowner_vacancy', 'rental_vacancy'],
#       dtype='object')

# %%
sql = '''
        DROP TABLE IF EXISTS races CASCADE;

        CREATE TABLE races (
            fips int,
            hispanic_pop int,
            white_pop int,
            black_pop int,
            native_pop int,
            asian_pop int, 
            pacific_islander_pop int,
            other_race_pop int,
            bi_tri_racial_pop int,
            PRIMARY KEY (fips)
        );
        
        INSERT INTO races (fips, hispanic_pop, white_pop, black_pop, native_pop, asian_pop, pacific_islander_pop, other_race_pop, bi_tri_racial_pop)
        SELECT jhu_cre_cases_deaths.fips, jhu_cre_cases_deaths.hispanic_pop, 
            jhu_cre_cases_deaths.white_pop, jhu_cre_cases_deaths.black_pop, jhu_cre_cases_deaths.native_pop,
            jhu_cre_cases_deaths.asian_pop, jhu_cre_cases_deaths.pacific_islander_pop, jhu_cre_cases_deaths.other_race_pop,
            jhu_cre_cases_deaths.bi_tri_racial_pop
        FROM jhu_cre_cases_deaths;
        
        SELECT * FROM races

'''

with engine.connect() as conn:
    query = conn.execute(text(sql))
output = pd.DataFrame(query.fetchall())
output
# Out:
#        fips  hispanic_pop  white_pop  black_pop  native_pop  asian_pop  \
# 0      1001          1559      41543      10580         167        556
# 1      1003         10207     184397      20414        1553       1997
# 2      1005           969      10086      10438          66        110
# 3      1007           530      15192       4506          20         20
# 4      1009          5365      50138        865          57        230
# ...     ...           ...        ...        ...         ...        ...
# 3137  56037          6660      33342        460         418        293
# 3138  56039          3508      19016        280          70        304
# 3139  56041          1836      17660         20         141         40
# 3140  56043          1098       6337          0          38          0
# 3141  56045            73       6424         13          13         53
#
#       pacific_islander_pop  other_race_pop  bi_tri_racial_pop
# 0                        0             111               1169
# 1                        0             443               3328
# 2                        0              88                264
# 3                        0               0                101
# 4                        0             230                865
# ...                    ...             ...                ...
# 3137                     0               0                670
# 3138                    23               0                163
# 3139                     0               0                484
# 3140                     0              15                239
# 3141                     6               0                 86
#
# [3142 rows x 9 columns]

# %%
sql = '''
        DROP TABLE IF EXISTS cases;

        CREATE TABLE cases (
            fips int,
            cases int,
            deaths int,
            PRIMARY KEY (fips),
            FOREIGN KEY (fips) REFERENCES races(fips)
        );
        
        INSERT INTO cases (fips, cases, deaths)
        SELECT jhu_cre_cases_deaths.fips, jhu_cre_cases_deaths.cases, jhu_cre_cases_deaths.deaths
        FROM jhu_cre_cases_deaths;
        
        SELECT * FROM cases

'''

with engine.connect() as conn:
    query = conn.execute(text(sql))
output = pd.DataFrame(query.fetchall())
output
# Out:
#        fips  cases  deaths
# 0      1001  19732     230
# 1      1003  69641     724
# 2      1005   7451     103
# 3      1007   8067     109
# 4      1009  18616     261
# ...     ...    ...     ...
# 3137  56037  12484     139
# 3138  56039  12123      16
# 3139  56041   6378      43
# 3140  56043   2749      50
# 3141  56045   1903      23
#
# [3142 rows x 3 columns]

# %%
sql = '''
        SELECT cases.fips, cases.cases, cases.deaths, races.white_pop, races.black_pop, races.native_pop, races.asian_pop, races.pacific_islander_pop, races.bi_tri_racial_pop, races.other_race_pop
        FROM cases
        INNER JOIN races ON cases.fips = races.fips;
'''

with engine.connect() as conn:
    query = conn.execute(text(sql))
ouput = pd.DataFrame(query.fetchall())
ouput
# Out:
#        fips  cases  deaths  white_pop  black_pop  native_pop  asian_pop  \
# 0      1001  19732     230      41543      10580         167        556
# 1      1003  69641     724     184397      20414        1553       1997
# 2      1005   7451     103      10086      10438          66        110
# 3      1007   8067     109      15192       4506          20         20
# 4      1009  18616     261      50138        865          57        230
# ...     ...    ...     ...        ...        ...         ...        ...
# 3137  56037  12484     139      33342        460         418        293
# 3138  56039  12123      16      19016        280          70        304
# 3139  56041   6378      43      17660         20         141         40
# 3140  56043   2749      50       6337          0          38          0
# 3141  56045   1903      23       6424         13          13         53
#
#       pacific_islander_pop  bi_tri_racial_pop  other_race_pop
# 0                        0               1169             111
# 1                        0               3328             443
# 2                        0                264              88
# 3                        0                101               0
# 4                        0                865             230
# ...                    ...                ...             ...
# 3137                     0                670               0
# 3138                    23                163               0
# 3139                     0                484               0
# 3140                     0                239              15
# 3141                     6                 86               0
#
# [3142 rows x 10 columns]

# %%
sql = '''
        DROP TABLE IF EXISTS case_race;

        SELECT cases.fips, cases.cases, cases.deaths, races.white_pop, races.black_pop, races.native_pop, races.asian_pop, races.pacific_islander_pop, races.bi_tri_racial_pop, races.other_race_pop
        INTO case_race
        FROM cases
        INNER JOIN races ON cases.fips = races.fips;
        
        SELECT * FROM cases
'''

with engine.connect() as conn:
    query = conn.execute(text(sql))
ouput = pd.DataFrame(query.fetchall())
ouput
# Out:
#        fips  cases  deaths
# 0      1001  19732     230
# 1      1003  69641     724
# 2      1005   7451     103
# 3      1007   8067     109
# 4      1009  18616     261
# ...     ...    ...     ...
# 3137  56037  12484     139
# 3138  56039  12123      16
# 3139  56041   6378      43
# 3140  56043   2749      50
# 3141  56045   1903      23
#
# [3142 rows x 3 columns]
