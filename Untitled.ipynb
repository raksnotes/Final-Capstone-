# %%
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from flask import Flask, jsonify
from sqlalchemy.engine import url
import json
from sqlalchemy import extract
from sqlalchemy.engine import make_url
import psycopg2
from sqlalchemy.sql import text
import os
data = os.path.join("JHU_Cases_Deaths_with_CRE_Data_2_0.csv")

df = pd.read_csv(data)

df.columns
# Out:
# Index(['fips', 'cases', 'deaths', 'lat', 'long', 'state', 'county', 'popuni',
#        'total_population', 'zero_rf', 'one_two_rf', 'three_rf',
#        'housing_units', 'hispanic_pop', 'white_pop', 'black_pop', 'native_pop',
#        'asian_pop', 'pacific_islander_pop', 'other_race_pop',
#        'bi_tri_racial_pop', 'male_pop', 'female_pop', 'veteran',
#        'gini_ind_income', 'rural_pop', 'median_age_pop', 'elder_pop',
#        'disability_pop', 'below_poverty_level', 'single_mothers_pop',
#        'single_fathers_pop', 'plus_family_homes', 'highschool_grad',
#        'multilingual_5yrs_plus', 'full_time_workers', 'no_health_insur',
#        'internet_homes', 'no_vehicle', 'homeowner_vacancy', 'rental_vacancy'],
#       dtype='object')

# %%
# Define the death thresholds
death_catlow = 47
death_catmed = 110
death_catintermed = 261
death_cathigh = 369


# Iterate over each row and assign a category based on the 'deaths' column
for (index, row) in df.iterrows():
    deaths = row['deaths']
    if deaths <= death_catlow:
        df.at[index, 'death_cat'] = 'low'
    elif deaths <= death_catmed:
        df.at[index, 'death_cat'] = 'med'
    elif deaths <= death_catintermed:
        df.at[index, 'death_cat'] = 'intermed'
    else:
        df.at[index, 'death_cat'] = 'high'

# %%
df.drop(columns=(["lat","long","state","county","fips",'popuni','total_population','cases', 'deaths']), inplace= True)

# %%
df.columns
# Out:
# Index(['zero_rf', 'one_two_rf', 'three_rf', 'housing_units', 'hispanic_pop',
#        'white_pop', 'black_pop', 'native_pop', 'asian_pop',
#        'pacific_islander_pop', 'other_race_pop', 'bi_tri_racial_pop',
#        'male_pop', 'female_pop', 'veteran', 'gini_ind_income', 'rural_pop',
#        'median_age_pop', 'elder_pop', 'disability_pop', 'below_poverty_level',
#        'single_mothers_pop', 'single_fathers_pop', 'plus_family_homes',
#        'highschool_grad', 'multilingual_5yrs_plus', 'full_time_workers',
#        'no_health_insur', 'internet_homes', 'no_vehicle', 'homeowner_vacancy',
#        'rental_vacancy', 'death_cat'],
#       dtype='object')

# %%
import pandas as pd
import sklearn
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
#PCA (Principal Component Analysis)
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
from sklearn.preprocessing import LabelEncoder
df['death_cat'] = LabelEncoder().fit_transform(df['death_cat'])

# %%
df.head()
# Out:
#    zero_rf  one_two_rf  three_rf  housing_units  hispanic_pop  white_pop  \
# 0    20573       22750     12365          23493          1559      41543
# 1    78622       90552     52724         114164         10207     184397
# 2     5024        9171      7828          12013           969      10086
# 3     6280        8986      5127           9185           530      15192
# 4    18189       23950     15558          24323          5365      50138
#
#    black_pop  native_pop  asian_pop  pacific_islander_pop  ...  \
# 0      10580         167        556                     0  ...
# 1      20414        1553       1997                     0  ...
# 2      10438          66        110                     0  ...
# 3       4506          20         20                     0  ...
# 4        865          57        230                     0  ...
#
#    plus_family_homes  highschool_grad  multilingual_5yrs_plus  \
# 0                111            49283                     779
# 1                887           201483                    3994
# 2                132            16120                     572
# 3                163            16130                     265
# 4                115            46446                    1961
#
#    full_time_workers  no_health_insur  internet_homes  no_vehicle  \
# 0              29291             3953           44884        2450
# 1             112058            19748          181512        7322
# 2               8170             2488           13323        2246
# 3               8096             2182           14111        1264
# 4              27463             6231           42118        2365
#
#    homeowner_vacancy  rental_vacancy  death_cat
# 0                779            1726          1
# 1               7322           96747          0
# 2                836            1629          3
# 3                305            1142          3
# 4                403            4846          1
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['zero_rf', 'one_two_rf', 'three_rf', 'housing_units', 'hispanic_pop',
#        'white_pop', 'black_pop', 'native_pop', 'asian_pop',
#        'pacific_islander_pop', 'other_race_pop', 'bi_tri_racial_pop',
#        'male_pop', 'female_pop', 'veteran', 'gini_ind_income', 'rural_pop',
#        'median_age_pop', 'elder_pop', 'disability_pop', 'below_poverty_level',
#        'single_mothers_pop', 'single_fathers_pop', 'plus_family_homes',
#        'highschool_grad', 'multilingual_5yrs_plus', 'full_time_workers',
#        'no_health_insur', 'internet_homes', 'no_vehicle', 'homeowner_vacancy',
#        'rental_vacancy', 'death_cat'],
#       dtype='object')

# %%
# Loop over all columns and run logistic regression

columns = df.columns.tolist()


for column in columns:

    X = df[[column]]
    y = df['death_cat']

    # Scale the data
#     scaler = StandardScaler()
#     X_scaled = scaler.fit_transform(X)
    
    from sklearn.preprocessing import MinMaxScaler

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    #split the data into training

    X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=50, stratify= y, test_size=0.20)


    # Building logistic regression model on training data
    classifier = LogisticRegression(max_iter=5000,random_state=50).fit(X_train, y_train)
    death_pred = classifier.predict(X_test)

    print(f"Training Data Score: {classifier.score(X_train, y_train)}")
    
    
    print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
    
    # Accuracy statistics
    
    print(f"Column: {column}, Accuracy Score: {metrics.accuracy_score(y_test, death_pred)}")
    print("--------------------------------------------------------------------------------")
# Out:
# Training Data Score: 0.24910465578989255
# Testing Data Score: 0.24960254372019078
# Column: zero_rf, Accuracy Score: 0.24960254372019078
# --------------------------------------------------------------------------------
# Training Data Score: 0.24910465578989255
# Testing Data Score: 0.24960254372019078
# Column: one_two_rf, Accuracy Score: 0.24960254372019078
# --------------------------------------------------------------------------------
# Training Data Score: 0.24910465578989255
# Testing Data Score: 0.24960254372019078
# Column: three_rf, Accuracy Score: 0.24960254372019078
# --------------------------------------------------------------------------------
# Training Data Score: 0.24910465578989255
# Testing Data Score: 0.24960254372019078
# Column: housing_units, Accuracy Score: 0.24960254372019078
# --------------------------------------------------------------------------------
# Training Data Score: 0.4552327894946279
# Testing Data Score: 0.48171701112877585
# Column: hispanic_pop, Accuracy Score: 0.48171701112877585
# --------------------------------------------------------------------------------
# Training Data Score: 0.24910465578989255
# Testing Data Score: 0.24960254372019078
# Column: white_pop, Accuracy Score: 0.24960254372019078
# --------------------------------------------------------------------------------
# Training Data Score: 0.46478312773577396
# Testing Data Score: 0.4594594594594595
# Column: black_pop, Accuracy Score: 0.4594594594594595
# --------------------------------------------------------------------------------
# Training Data Score: 0.3378432152805412
# Testing Data Score: 0.3481717011128776
# Column: native_pop, Accuracy Score: 0.3481717011128776
# --------------------------------------------------------------------------------
# Training Data Score: 0.4803024273776363
# Testing Data Score: 0.5087440381558028
# Column: asian_pop, Accuracy Score: 0.5087440381558028
# --------------------------------------------------------------------------------
# Training Data Score: 0.35694389176283325
# Testing Data Score: 0.3672496025437202
# Column: pacific_islander_pop, Accuracy Score: 0.3672496025437202
# --------------------------------------------------------------------------------
# Training Data Score: 0.4982093115797851
# Testing Data Score: 0.5119236883942766
# Column: other_race_pop, Accuracy Score: 0.5119236883942766
# --------------------------------------------------------------------------------
# Training Data Score: 0.5773975328292877
# Testing Data Score: 0.5993640699523053
# Column: bi_tri_racial_pop, Accuracy Score: 0.5993640699523053
# --------------------------------------------------------------------------------
# Training Data Score: 0.24910465578989255
# Testing Data Score: 0.24960254372019078
# Column: male_pop, Accuracy Score: 0.24960254372019078
# --------------------------------------------------------------------------------
# Training Data Score: 0.24910465578989255
# Testing Data Score: 0.24960254372019078
# Column: female_pop, Accuracy Score: 0.24960254372019078
# --------------------------------------------------------------------------------
# Training Data Score: 0.7043374452845205
# Testing Data Score: 0.6947535771065183
# Column: veteran, Accuracy Score: 0.6947535771065183
# --------------------------------------------------------------------------------
# Training Data Score: 0.754874651810585
# Testing Data Score: 0.7567567567567568
# Column: gini_ind_income, Accuracy Score: 0.7567567567567568
# --------------------------------------------------------------------------------
# Training Data Score: 0.2439315559092718
# Testing Data Score: 0.25119236883942764
# Column: rural_pop, Accuracy Score: 0.25119236883942764
# --------------------------------------------------------------------------------
# Training Data Score: 0.24910465578989255
# Testing Data Score: 0.24960254372019078
# Column: median_age_pop, Accuracy Score: 0.24960254372019078
# --------------------------------------------------------------------------------
# Training Data Score: 0.7401512136888182
# Testing Data Score: 0.7265500794912559
# Column: elder_pop, Accuracy Score: 0.7265500794912559
# --------------------------------------------------------------------------------
# Training Data Score: 0.7759649820931158
# Testing Data Score: 0.7774244833068362
# Column: disability_pop, Accuracy Score: 0.7774244833068362
# --------------------------------------------------------------------------------
# Training Data Score: 0.7373656983684839
# Testing Data Score: 0.7313195548489666
# Column: below_poverty_level, Accuracy Score: 0.7313195548489666
# --------------------------------------------------------------------------------
# Training Data Score: 0.7230401910067649
# Testing Data Score: 0.724960254372019
# Column: single_mothers_pop, Accuracy Score: 0.724960254372019
# --------------------------------------------------------------------------------
# Training Data Score: 0.6486271388778353
# Testing Data Score: 0.6597774244833068
# Column: single_fathers_pop, Accuracy Score: 0.6597774244833068
# --------------------------------------------------------------------------------
# Training Data Score: 0.5296458416235575
# Testing Data Score: 0.548489666136725
# Column: plus_family_homes, Accuracy Score: 0.548489666136725
# --------------------------------------------------------------------------------
# Training Data Score: 0.24910465578989255
# Testing Data Score: 0.24960254372019078
# Column: highschool_grad, Accuracy Score: 0.24960254372019078
# --------------------------------------------------------------------------------
# Training Data Score: 0.49224035017906886
# Testing Data Score: 0.505564387917329
# Column: multilingual_5yrs_plus, Accuracy Score: 0.505564387917329
# --------------------------------------------------------------------------------
# Training Data Score: 0.24910465578989255
# Testing Data Score: 0.24960254372019078
# Column: full_time_workers, Accuracy Score: 0.24960254372019078
# --------------------------------------------------------------------------------
# Training Data Score: 0.6820533227218464
# Testing Data Score: 0.670906200317965
# Column: no_health_insur, Accuracy Score: 0.670906200317965
# --------------------------------------------------------------------------------
# Training Data Score: 0.24910465578989255
# Testing Data Score: 0.24960254372019078
# Column: internet_homes, Accuracy Score: 0.24960254372019078
# --------------------------------------------------------------------------------
# Training Data Score: 0.7107043374452845
# Testing Data Score: 0.699523052464229
# Column: no_vehicle, Accuracy Score: 0.699523052464229
# --------------------------------------------------------------------------------
# Training Data Score: 0.6275368085953044
# Testing Data Score: 0.643879173290938
# Column: homeowner_vacancy, Accuracy Score: 0.643879173290938
# --------------------------------------------------------------------------------
# Training Data Score: 0.6207719856744927
# Testing Data Score: 0.6248012718600954
# Column: rental_vacancy, Accuracy Score: 0.6248012718600954
# --------------------------------------------------------------------------------
# Training Data Score: 1.0
# Testing Data Score: 1.0
# Column: death_cat, Accuracy Score: 1.0
# --------------------------------------------------------------------------------

# %%
'one_two_rf', 'three_rf','veteran', 'gini_ind_income','elder_pop', 'disability_pop', 'below_poverty_level',
'single_mothers_pop','no_vehicle'

# %%
X = df[['one_two_rf', 'three_rf','veteran', 'gini_ind_income','elder_pop', 'disability_pop', 'below_poverty_level',
'single_mothers_pop','no_vehicle']]
y = df['death_cat']

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=50, stratify= y, test_size=0.25)

# %%
classifier = LogisticRegression(max_iter=30000,random_state=50).fit(X_train, y_train)
death_pred = classifier.predict(X_test)
# Out:
# C:\Users\erick\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
    
    
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
    
    # Accuracy statistics
    
print(f"Column: {column}, Accuracy Score: {metrics.accuracy_score(y_test, death_pred)}")
print("--------------------------------------------------------------------------------")
# Out:
# Training Data Score: 0.7924448217317487
# Testing Data Score: 0.7862595419847328
# Column: death_cat, Accuracy Score: 0.7862595419847328
# --------------------------------------------------------------------------------
